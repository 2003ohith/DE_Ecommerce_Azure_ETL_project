# %%
catalog="Ecommerce"

# %% [markdown]
# ###***Order Items***

# %%
from pyspark.sql.functions import *
from pyspark.sql.types import *

Raw_data_path=f"/Volumes/{catalog}/raw/raw_landing/order_items/landing/"

df=spark.read.format('csv').option('inferSchema',True).option("header",True).load(Raw_data_path)
df=df.withColumn('Source_file',col("_metadata.file_path"))\
.withColumn('Ingested_at',current_timestamp())

df.write.format('delta').option('mergeSchema','true').mode('Overwrite').saveAsTable(f'{catalog}.bronze.Brz_Order_items_fact')

# %% [markdown]
# ###***Order Shipments***

# %%
from pyspark.sql.functions import *
from pyspark.sql.types import *

Raw_data_path=f"/Volumes/{catalog}/raw/raw_landing/order_shipments/landing/"

df=spark.read.format('csv').option('inferSchema',True).option("header",True).load(Raw_data_path)
df=df.withColumn('Source_file',col("_metadata.file_path"))\
.withColumn('Ingested_at',current_timestamp())

df.write.format('delta').option('mergeSchema','true').mode('Overwrite').saveAsTable(f'{catalog}.bronze.Brz_Order_Shipments_fact')

# %% [markdown]
# ###***Order Returns***

# %%
from pyspark.sql.functions import *
from pyspark.sql.types import *

Raw_data_path=f"/Volumes/{catalog}/raw/raw_landing/order_returns/landing/"

df=spark.read.format('csv').option('inferSchema',True).option("header",True).load(Raw_data_path)
df=df.withColumn('Source_file',col("_metadata.file_path"))\
.withColumn('Ingested_at',current_timestamp())

df.write.format('delta').option('mergeSchema','true').mode('Overwrite').saveAsTable(f'{catalog}.bronze.Brz_Order_Returns_fact')
