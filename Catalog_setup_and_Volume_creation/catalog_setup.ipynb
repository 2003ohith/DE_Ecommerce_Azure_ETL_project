# %% [markdown]
# ###**Ecommerce Under **UC** catalog**

# %%
# %sql
create catalog if not exists Ecommerce
managed location 'abfss://uc-data-ecom@stgactexomdevus001.dfs.core.windows.net/Ecom-catalog'
comment 'Ecommerce Catalog handled by UC';

# %%
# %sql
use catalog ecommerce;

# %%
# %sql
create schema if not exists Bronze;
create schema if not exists Silver;
create schema if not exists Gold;

# %%
# %sql
create catalog sample;

# %%
# %sql
use catalog ecommerce;

# %% [markdown]
# ###**Raw Schema setup External Volume**

# %%
# %sql
create Schema if not exists Raw

# %%
# %sql
create External volume if not exists Raw.Raw_landing
location 'abfss://raw-data@stgactexomdevus001.dfs.core.windows.net/'
comment 'Raw Volume creation';
