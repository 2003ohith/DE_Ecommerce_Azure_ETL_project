# %%
catalog="Ecommerce"

# %% [markdown]
# ###***Brands***

# %%
from pyspark.sql.functions import *
from pyspark.sql.types import *

brand_Schema=StructType([
  StructField("brand_code", StringType(), False),
  StructField("brand_name", StringType(), True),
  StructField("category_code", StringType(), True)])

Raw_data_path=f"/Volumes/{catalog}/raw/raw_landing/brands/brands.csv"

df=spark.read.format('csv').schema(brand_Schema).option("header",True).load(Raw_data_path)
df=df.withColumn('Source_file',col("_metadata.file_path"))\
.withColumn('Ingested_at',current_timestamp())

df.limit(10).display()


df.write.format('delta').option('mergeSchema','true').mode('Overwrite').saveAsTable(f'{catalog}.bronze.Brz_Brands')

# %% [markdown]
# ###***Category***

# %%
from pyspark.sql.functions import *
from pyspark.sql.types import *

Category_Schema=StructType([
  StructField("category_code", StringType(), False),
  StructField("category_name", StringType(), True)])

Raw_data_path=f"/Volumes/{catalog}/raw/raw_landing/category/category.csv"

df=spark.read.format('csv').schema(Category_Schema).option("header",True).load(Raw_data_path)
df=df.withColumn('Source_file',col("_metadata.file_path"))\
.withColumn('Ingested_at',current_timestamp())

df.limit(10).display()


df.write.format('delta').option('mergeSchema','true').mode('Overwrite').saveAsTable(f'{catalog}.bronze.Brz_Category')

# %% [markdown]
# ###***Customers***

# %%
from pyspark.sql.functions import *
from pyspark.sql.types import *

customers_Schema=StructType([
  StructField("customer_id", StringType(), False),
  StructField("Phone", StringType(), True),
  StructField("Country_code",StringType(),True),
  StructField("Country",StringType(),True),
  StructField("State",StringType(),True)
])

Raw_data_path=f"/Volumes/{catalog}/raw/raw_landing/customers/customers.csv"

df=spark.read.format('csv').schema(customers_Schema).option("header",True).load(Raw_data_path)
df=df.withColumn('Source_file',col("_metadata.file_path"))\
.withColumn('Ingested_at',current_timestamp())

df.limit(20).display()


df.write.format('delta').option('mergeSchema','true').mode('Overwrite').saveAsTable(f'{catalog}.bronze.Brz_Customers')

# %% [markdown]
# ###***Products***

# %%
from pyspark.sql.functions import *
from pyspark.sql.types import *

products_schema = StructType([
    StructField("product_id", StringType(), False),
    StructField("sku", StringType(), True),
    StructField("category_code", StringType(), True),
    StructField("brand_code", StringType(), True),
    StructField("color", StringType(), True),
    StructField("size", StringType(), True),
    StructField("material", StringType(), True),
    StructField("weight_gr", StringType(), True),  #datatype is string due to incoming data contain anamolies
    StructField("length_cm", StringType(), True),  #datatype is string due to incoming data contain anamolies
    StructField("width_cm", FloatType(), True),
    StructField("height_cm", FloatType(), True),
    StructField("rating_count", IntegerType(), True)
])

Raw_data_path=f"/Volumes/{catalog}/raw/raw_landing/products/products.csv"

df=spark.read.format('csv').schema(products_schema).option("header",True).load(Raw_data_path)
df=df.withColumn('Source_file',col("_metadata.file_path"))\
.withColumn('Ingested_at',current_timestamp())

df.limit(20).display()



df.write.format('delta').option('mergeSchema','true').mode('Overwrite').saveAsTable(f'{catalog}.bronze.Brz_products')

# %% [markdown]
# ###***Date***

# %%
from pyspark.sql.functions import *
from pyspark.sql.types import *

date_schema = StructType([
 StructField("date", DateType(), True),                  # Raw date in string format
    StructField("year", IntegerType(), True),               # Year
    StructField("day_name", StringType(), True),           # Day name (can be mixed case)
    StructField("quarter", IntegerType(), True),           # Quarter
    StructField("week_of_year", IntegerType(), True)])     #Week of year

Raw_data_path=f"/Volumes/{catalog}/raw/raw_landing/date/date.csv"

df=spark.read.format('csv').schema(date_schema).option("header",True).load(Raw_data_path)
df=df.withColumn('Source_file',col("_metadata.file_path"))\
.withColumn('Ingested_at',current_timestamp())

df.limit(10).display()


df.write.format('delta').option('mergeSchema','true').mode('Overwrite').saveAsTable(f'{catalog}.bronze.Brz_Dates')

# %% [markdown]
# ###***Order items***

# %%
from pyspark.sql.functions import *
from pyspark.sql.types import *

Raw_data_path=f"/Volumes/{catalog}/raw/raw_landing/order_items/landing/"

df=spark.read.format('csv').option('inferSchema', True).option("header",True).load(Raw_data_path)
df=df.withColumn('Source_file',col("_metadata.file_path"))\
.withColumn('Ingested_at',current_timestamp())

df.limit(10).display()
df_s = df.select(
    max("dt").alias("max_date"),
    min("dt").alias("min_date")
)

df_s.display()

# %%
catalog='Ecommerce'
Raw_data_path=f"/Volumes/{catalog}/raw/raw_landing/products/products.csv"

df=spark.read.format('csv').option("header",True).load(Raw_data_path)
df.limit(30).display()
